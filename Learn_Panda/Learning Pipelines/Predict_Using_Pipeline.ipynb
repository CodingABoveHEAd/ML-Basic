# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('titanic_pipeline.pkl', 'rb'))

# %%
#user input
test_input=np.array([2,'female',26.0,0,0,10.0,'S']).reshape(1,7)
test_input
# Out:
# array([['2', 'female', '26.0', '0', '0', '10.0', 'S']], dtype='<U32')

# %%
pipe.predict(test_input)
# Out:
# d:\ML-Basic\Learn_Panda\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# d:\ML-Basic\Learn_Panda\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
