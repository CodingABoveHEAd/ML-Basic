# %%
#word tokenization
text="I am going to the market."
text.split()
# Out:
# ['I', 'am', 'going', 'to', 'the', 'market.']

# %%
#sentence tokenization
text2="Hello there.How are you.I am fine."
sentences=text2.split('.')
sentences
# Out:
# ['Hello there', 'How are you', 'I am fine', '']

# %%
#problem with simple split method
text3="Dr. Smith is from the U.S.A. He arrived at 5 p.m. on Jan. 3rd."
sentences2=text3.split('.')
sentences2
# Out:
# ['Dr',
#  ' Smith is from the U',
#  'S',
#  'A',
#  ' He arrived at 5 p',
#  'm',
#  ' on Jan',
#  ' 3rd',
#  '']

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\NILOY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\NILOY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
sentences3=sent_tokenize(text3)
sentences3
# Out:
# ['Dr. Smith is from the U.S.A.', 'He arrived at 5 p.m. on Jan. 3rd.']

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
doc=nlp(text3)
for sent in doc.sents:
    print(sent)

# %%
from transformers import XLMRobertaTokenizer

# Load the tokenizer (example with XLM-RoBERTa base)
tokenizer = XLMRobertaTokenizer.from_pretrained("xlm-roberta-base")

# Example usage
text = "tmi kmn acho"  # Banglish sentence
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['▁t', 'mi', '▁km', 'n', '▁acho']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
